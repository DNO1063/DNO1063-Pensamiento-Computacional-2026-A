# %% [markdown]
# # M01_E01_Intro_Python
#
# ### PENSAMIENTO COMPUTACIONAL
#
# * Prof. Ricardo Vega M. - Escuela de Diseño Universidad Católica de Chile.
#
# * Renombrar archivo así: E0{número_de_ejercicio}_apellido_nombre_rut, por ejemplo:
# E01_PRINT_SUMAR_vega_ricardo_102349285
#
# * Renombrar el titulo asi: E01_PRINT_SUMAR_apellido_nombre_rut, por ejemplo:
# E01_PRINT_SUMAR_vega_ricardo_102349285

# %% [markdown]
# **¿Qué es Python?**.
#
# Python es un lenguaje de programación de alto nivel, interpretado y de código abierto, reconocido por su sintaxis clara, legible y simple, similar al idioma inglés. Es un lenguaje de propósito general, lo que significa que está diseñado para ser utilizado en una serie de aplicaciones, incluyendo ciencias de datos, desarrollo de software y web, automatización y, muchas otras cosas
#
# **¿En que cosas se usa Python?**.
# Se utiliza para crear programas en diversas áreas: Desarrollo de aplicaciones web; Desarrollo de software; Ciencia de datos; Machine learning; Automatización de tareas; Análisis de datos; Aprendizaje automático; Visualización de datos; Uso de APIs, etc.
#
# **¿Quién creó Python?**.
# Python fue creado en 1991 por Guido van Rossum, con una filosofía hace hincapié en la legibilidad de su código. Un dato curioso es que el hermano de Guido, Just van Rosum, es un diseñador especializado en tipografía.

# %% [markdown]
# **¿Como fuinciona Python?**.
#
# Los lenguajes de programación como Python, tienen una serie de funciones, o "palabras" clave que se usan para programar.
#
# También tiene ciertas estructuras que permiten controlar el flujo del programa. Las principales que veremos ahora son estas:
#
# - Variables
# - Decisiones, if, else, elif
# - Funciones nativas
# - Ciclos
# - Listas o Arrays
# - Recorrer listas

# %% [markdown]
# ## A– Variables
# ### Tipos de Variable:
#
# palabra = "Python"
#
# número = 42
#
# decimales = 2.87
#
# frutas(lista) = ["manzana", "mango", "uva"]
#
#
# Se puede pensar en las variables como una cajita con un nombre en donde se guardan valores que se pueden usar después.
#
# Podemos saber el tipo de variable usando la función type()

# %%
a = 4
t = '5'
print( a )
print( t )
print( type(a) )
print( type(t) )

# %%
## Se pueden hacer operaciones aritméticas.
a = 5
b = 4
c = a + b
print( c )

# %%
## Se pueden reescribir los valores de las variables
a = 1
c = 1.5
c = 2.5
print( a+c )

# %%
## Se pueden guardar textos también!
c = "Hola"
n = 'Juan'
x = 2
print( c, n, x )

# %% [markdown]
# ## B– Decisiones, if, else, elif
# Es la manera en que el computador toma desiciones, preguntando si un valor es tal o cual.

# %%
## Probar cambiando el valor de a
a = 3

if a == 5:
    print("a vale 5")
else:
    print("a NO vale 5")

# %% [markdown]
# ## C– Funciones nativas
#   Python cuenta con un enorme repertorio de funciones nativas que facilitan la implementación de código:
#
#   ### 1. print()

# %%
print("Hola Mundo")
print(":)")
print(1234)
print([1,2,3])

# %% [markdown]
#   ### 2. type()

# %%
a = 1495
b = "Chao Mundo"
c = ["pancho", "rodrio", "ari", "feña", "cata", "nini", "santi"]
print( type(a) )
print( type(b) )
print( type(c) )

# %% [markdown]
# ### 3. len()

# %%
a = "textomuyextremadamentelargo"
print(len(a))
b = ["lista", 1239, "número", 384.23]
print(len(b))

# %% [markdown]
# ### 4. range()
#
# La función range() devuelve una secuencia de números, comenzando desde 0 por defecto, incrementándose en 1 (por defecto) y deteniéndose antes de un número especificado.

# %%
a = range(8)
print(a)
b = range (2, 9)
print(b)

# %% [markdown]
# ## C– Ciclos
# Permite repetir instrucciones según un límite.

# %%
## Para cada elemento i, entre 0 y 5, se hace lo siguiente...
for i in range( 6 ):
    print( "i Vale: ", i )

# %% [markdown]
# ## D– Listas o Arrays
# Sirve para tener un conjunto ordenado de elementos, pudiendo ser estos todo tipo de variables (números, palabras, floats, listas, etc).

# %%
## En este caso son textos que van entre comillas.
nombres = ['Ana','Beatriz','Claudia','Diana','Elvira','Fernanda','Gabriela']
print( nombres[ 4 ] ) ## cambiar valor entre los paréntesis cuadrados para acceder a otro nombre de la lista

# %% [markdown]
# ## E– Recorrer listas
# Se puede recorrer una lista con un ciclo.

# %%
## Toma cada elemento n de la lista nombres
for n in range( len(nombres) ): ## len(nombres) indica la cantidad de elementos de la lista nombres
    print( n, nombres[ n ] )

# %%
## Toma cada elemento n de la lista nombres
for n in ( nombres ): ## len(nombres) indica la cantidad de elementos de la lista nombres
    print( n )

# %%
## Podemos tener listas de números también!
edades = [23,18,54,29,43,41,33]

for e in range( len(edades) ): ## len(nombres) indica la cantidad de elementos de la lista nombres
    print( edades[ e ] )

# %% [markdown]
# ## Ahora Usted:
#
# Recordar que debe crear las celdas correspondientes.

# %% [markdown]
# ## 1– Imprimir Nombres (1 punto)
#
# Crear dos variables "nomb" y "apell", y guardar en ellos su nombre y apellido respectivamente. Luego imprimirlos usando la función print().

# %%
## Su respuesta desde acá.

# %% [markdown]
# ## 2– Lista de strings (palabras) (1 punto)
#
# Hacer una lista con 5 elementos, pueden ser nombres de sus amigos, cantantes, mascotas, lo que estime. Recorrerlo con un ciclo for mostrando con un print cada elemento (como en el ejemplo de más arriba).

# %%
## Su respuesta desde acá.

# %% [markdown]
# ## 3–  Lista de ints (números)  (1 punto)
#
# Hacer una lista con edades ficticias de sus amigos, cantantes, mascotas, lo que estime. Recorrerlo con un ciclo for mostrando con un print cada elemento (como en el ejemplo de más arriba).

# %%
## Su respuesta desde acá.

# %% [markdown]
# ## 4– Sumar numeros del RUT (1 punto)
#
# Poner los números de su RUT en una lista, sumarlos en una nueva variable, y mostrar el resultado con el mensaje "Mi rut suma:" XX (donde XX es el resultado de la suma)
#
# Ayuda: puede usar este código. "?" indica que hay un valor a reemplazar

# %%
## EJEMPLO

rut_num = [2, 4, completar c sus numeros...]

suma = 0

for i in range( len(rut_num) ):
  suma = suma + rut_num[?]

frase = "Mi rut suma:"
print( frase, ? )

# %%
## Su respuesta desde acá (copiar código de arriba).

# %% [markdown]
# ## 5– Evaluar cantidad de animalitos con if (2 punto)
#
# Completar la estructura de desición con los valores que correpondan. El resultado al imprimir debe ser este:
#
# Hay menos gatitos, son: 12
# El total de animalitos es: 36

# %%
## Colocar en ? el dato que corresponda.

gatitos  = ?
perritos = 24

if gatitos > perritos:
    print("Hay más gatitos, son:", ? )
else:
    print("Hay menos gatitos, son:", ?)


# sumar cantidad de animalitos
mensaje = "El total de animalitos es:"
tot = ? + perritos

print( ?, ? )
